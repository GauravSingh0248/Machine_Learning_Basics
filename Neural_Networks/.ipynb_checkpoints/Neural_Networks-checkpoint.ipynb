# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons, make_circles, make_classification

# %%
# X, Y = make_moons(n_samples=2000, noise=0.15, random_state=1)
# X, Y = make_circles(n_samples=2000, noise=0.1, random_state=1, factor=0.5)
# X, Y = make_classification(n_samples=2000, n_features=2, n_redundant=0, random_state=1)

# %%
print(X.shape,Y.shape)
plt.scatter(X[:,0],X[:,1],c=Y)
# Out:
# (2000, 2) (2000,)

# %%
def load_dataset(dataset):
    if dataset=='moons':
        X, Y = make_moons(n_samples=10000, noise=0.15, random_state=1)
    elif dataset=='circles':
        X, Y = make_circles(n_samples=10000, noise=0.1, random_state=1, factor=0.5)
    elif dataset=='classification':
        X, Y = make_classification(n_samples=10000, n_features=2, n_redundant=0, random_state=2)

    return X,Y

# %%
dataset = 'circles'
X,Y = load_dataset(dataset)
print(X.shape, Y.shape)
# Out:
# (10000, 2) (10000,)

# %%
plt.scatter(X[:, 0], X[:, 1], c = Y)
plt.show()

# %% [markdown]
# # Model Building

# %%
from keras import Sequential
from keras.layers import Dense

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(2,)))  # input shape for the first hidden layer
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_17 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 5)                   │              55 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 91 (364.00 B)
#  Trainable params: 91 (364.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, Y, batch_size = 64, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5339 - loss: 0.6565 - val_accuracy: 0.7280 - val_loss: 0.6052
# Epoch 2/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8050 - loss: 0.5812 - val_accuracy: 0.9100 - val_loss: 0.5125
# Epoch 3/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9396 - loss: 0.4837 - val_accuracy: 0.9760 - val_loss: 0.4036
# Epoch 4/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9772 - loss: 0.3697 - val_accuracy: 0.9850 - val_loss: 0.2914
# Epoch 5/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9859 - loss: 0.2629 - val_accuracy: 0.9900 - val_loss: 0.1976
# Epoch 6/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9887 - loss: 0.1732 - val_accuracy: 0.9900 - val_loss: 0.1308
# Epoch 7/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.1136 - val_accuracy: 0.9930 - val_loss: 0.0900
# Epoch 8/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0778 - val_accuracy: 0.9930 - val_loss: 0.0668
# Epoch 9/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0546 - val_accuracy: 0.9920 - val_loss: 0.0536
# Epoch 10/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0465 - val_accuracy: 0.9920 - val_loss: 0.0451
# Epoch 11/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9901 - loss: 0.0420 - val_accuracy: 0.9930 - val_loss: 0.0390
# Epoch 12/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9914 - loss: 0.0363 - val_accuracy: 0.9920 - val_loss: 0.0360
# Epoch 13/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9907 - loss: 0.0319 - val_accuracy: 0.9920 - val_loss: 0.0322
# Epoch 14/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9925 - loss: 0.0287 - val_accuracy: 0.9920 - val_loss: 0.0304
# Epoch 15/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9899 - loss: 0.0323 - val_accuracy: 0.9920 - val_loss: 0.0282
# Epoch 16/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9910 - loss: 0.0271 - val_accuracy: 0.9930 - val_loss: 0.0274
# Epoch 17/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.0274 - val_accuracy: 0.9930 - val_loss: 0.0254
# Epoch 18/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.0230 - val_accuracy: 0.9940 - val_loss: 0.0253
# Epoch 19/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0233 - val_accuracy: 0.9940 - val_loss: 0.0247
# Epoch 20/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9916 - loss: 0.0252 - val_accuracy: 0.9950 - val_loss: 0.0231
# Epoch 21/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9905 - loss: 0.0264 - val_accuracy: 0.9950 - val_loss: 0.0225
# Epoch 22/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9935 - loss: 0.0203 - val_accuracy: 0.9950 - val_loss: 0.0220
# Epoch 23/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9911 - loss: 0.0269 - val_accuracy: 0.9940 - val_loss: 0.0225
# Epoch 24/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9931 - loss: 0.0211 - val_accuracy: 0.9950 - val_loss: 0.0206
# Epoch 25/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9933 - loss: 0.0206 - val_accuracy: 0.9940 - val_loss: 0.0198
# Epoch 26/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0224 - val_accuracy: 0.9950 - val_loss: 0.0214
# Epoch 27/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9892 - loss: 0.0271 - val_accuracy: 0.9950 - val_loss: 0.0200
# Epoch 28/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0194 - val_accuracy: 0.9950 - val_loss: 0.0188
# Epoch 29/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0200 - val_accuracy: 0.9940 - val_loss: 0.0191
# Epoch 30/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0222 - val_accuracy: 0.9930 - val_loss: 0.0213
# Epoch 31/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9938 - loss: 0.0195 - val_accuracy: 0.9940 - val_loss: 0.0184
# Epoch 32/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9925 - loss: 0.0197 - val_accuracy: 0.9950 - val_loss: 0.0178
# Epoch 33/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9928 - loss: 0.0233 - val_accuracy: 0.9940 - val_loss: 0.0189
# Epoch 34/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9950 - loss: 0.0169 - val_accuracy: 0.9950 - val_loss: 0.0179
# Epoch 35/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9924 - loss: 0.0215 - val_accuracy: 0.9960 - val_loss: 0.0189
# Epoch 36/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.0250 - val_accuracy: 0.9960 - val_loss: 0.0175
# Epoch 37/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0230 - val_accuracy: 0.9920 - val_loss: 0.0198
# Epoch 38/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9927 - loss: 0.0204 - val_accuracy: 0.9960 - val_loss: 0.0181
# Epoch 39/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9913 - loss: 0.0226 - val_accuracy: 0.9960 - val_loss: 0.0173
# Epoch 40/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0213 - val_accuracy: 0.9940 - val_loss: 0.0169
# Epoch 41/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9938 - loss: 0.0183 - val_accuracy: 0.9950 - val_loss: 0.0177
# Epoch 42/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.0195 - val_accuracy: 0.9950 - val_loss: 0.0176
# Epoch 43/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0195 - val_accuracy: 0.9950 - val_loss: 0.0180
# Epoch 44/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - loss: 0.0184 - val_accuracy: 0.9940 - val_loss: 0.0174
# Epoch 45/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9927 - loss: 0.0214 - val_accuracy: 0.9940 - val_loss: 0.0172
# Epoch 46/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9940 - loss: 0.0182 - val_accuracy: 0.9930 - val_loss: 0.0184
# Epoch 47/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.0203 - val_accuracy: 0.9960 - val_loss: 0.0177
# Epoch 48/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9932 - loss: 0.0182 - val_accuracy: 0.9940 - val_loss: 0.0170
# Epoch 49/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - loss: 0.0178 - val_accuracy: 0.9940 - val_loss: 0.0170
# Epoch 50/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9923 - loss: 0.0198 - val_accuracy: 0.9950 - val_loss: 0.0165

# %%
# Out:
# <Sequential name=sequential_4, built=True>
